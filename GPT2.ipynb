# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', device="cuda", model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, truncation=True, num_return_sequences=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# [{'generated_text': 'Hello, I\'m a language model, so you can\'t define something in any other language. Let me introduce another topic:\n\nThe name "'},
#  {'generated_text': "Hello, I'm a language model, you know.\n\nThat's right… I have a lot of friends who don't know what I do"},
#  {'generated_text': "Hello, I'm a language model, not a formal one. I'm more interested in languages than formal models and I'm going to use the formal"},
#  {'generated_text': "Hello, I'm a language model, and I have two languages, one my native, and one one my Portuguese, so... I've got a"},
#  {'generated_text': "Hello, I'm a language model,\n\nAnd you know I have lots of problems.\n\nThe grammar is not just bad but annoying because"}]

# %%
import torch

# %%
with open('tinyshakespeare.txt', 'r') as f:
    text = f.read()
data = text[:1000]

# %%
import tiktoken
enc = tiktoken.get_encoding('gpt2')
tokens = enc.encode(data)
print(tokens[:24])
# Out:
# [5962, 22307, 25, 198, 8421, 356, 5120, 597, 2252, 11, 3285, 502, 2740, 13, 198, 198, 3237, 25, 198, 5248, 461, 11, 2740, 13]

# %%
a = enc.encode('I am')
a = torch.tensor(a).unsqueeze(0)
print(repr(a.tolist()))
enc.decode(a.squeeze().tolist())
# Out:
# [[40, 716]]
# 'I am'

# %%
import torch
buf = torch.tensor(tokens[:24 + 1])
x = buf[:-1].view(4, 6)
y = buf[1:].view(4, 6)
print(x)
print(y)
# Out:
# tensor([[ 5962, 22307,    25,   198,  8421,   356],
#         [ 5120,   597,  2252,    11,  3285,   502],
#         [ 2740,    13,   198,   198,  3237,    25],
#         [  198,  5248,   461,    11,  2740,    13]])
# tensor([[22307,    25,   198,  8421,   356,  5120],
#         [  597,  2252,    11,  3285,   502,  2740],
#         [   13,   198,   198,  3237,    25,   198],
#         [ 5248,   461,    11,  2740,    13,   198]])

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# True
# 12.6

# %%
import torch
import numpy as np

@torch.compile
def f(a, b):
    return a + b

with torch.device("cuda"):
    f(np.array([1]), np.array([2]))
# Out:
# ---------------------------------------------------------------------------
# TorchRuntimeError                         Traceback (most recent call last)
# Cell In[2], line 9
#       6     return a + b
#       8 with torch.device("cuda"):
# ----> 9     f(np.array([1]), np.array([2]))
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\eval_frame.py:574, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     569 saved_dynamic_layer_stack_depth = (
#     570     torch._C._functorch.get_dynamic_layer_stack_depth()
#     571 )
#     573 try:
# --> 574     return fn(*args, **kwargs)
#     575 finally:
#     576     # Restore the dynamic layer stack depth if necessary.
#     577     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     578         saved_dynamic_layer_stack_depth
#     579     )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:1380, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1374             return hijacked_callback(
#    1375                 frame, cache_entry, self.hooks, frame_state
#    1376             )
#    1378 with compile_lock, _disable_current_modes():
#    1379     # skip=1: skip this frame
# -> 1380     return self._torchdynamo_orig_callable(
#    1381         frame, cache_entry, self.hooks, frame_state, skip=1
#    1382     )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:1164, in ConvertFrame.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#    1162 counters["frames"]["total"] += 1
#    1163 try:
# -> 1164     result = self._inner_convert(
#    1165         frame, cache_entry, hooks, frame_state, skip=skip + 1
#    1166     )
#    1167     counters["frames"]["ok"] += 1
#    1168     return result
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:547, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     544     dynamo_tls.traced_frame_infos.append(info)
#     546 with compile_context(CompileContext(compile_id)):
# --> 547     return _compile(
#     548         frame.f_code,
#     549         frame.f_globals,
#     550         frame.f_locals,
#     551         frame.f_builtins,
#     552         frame.closure,
#     553         self._torchdynamo_orig_callable,
#     554         self._one_graph,
#     555         self._export,
#     556         self._export_constraints,
#     557         hooks,
#     558         cache_entry,
#     559         cache_size,
#     560         frame,
#     561         frame_state=frame_state,
#     562         compile_id=compile_id,
#     563         skip=skip + 1,
#     564     )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:986, in _compile(code, globals, locals, builtins, closure, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     984 guarded_code = None
#     985 try:
# --> 986     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     988     # NB: We only put_code_state in success case.  Success case here
#     989     # does include graph breaks; specifically, if a graph break still
#     990     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)
#     995     # to upload for graph break though, because this can prevent
#     996     # extra graph break compilations.)
#     997     put_code_state()
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:715, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     713     stack.enter_context(torch._dynamo.callback_handler.install_callbacks())
#     714     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 715     return _compile_inner(code, one_graph, hooks, transform)
#     717 return None
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_utils_internal.py:95, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      92     kwargs["skip"] = skip + 1
#      94 if not StrobelightCompileTimeProfiler.enabled:
# ---> 95     return function(*args, **kwargs)
#      97 return StrobelightCompileTimeProfiler.profile_compile_time(
#      98     function, phase_name, *args, **kwargs
#      99 )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:750, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     748 CompileContext.get().attempt = attempt
#     749 try:
# --> 750     out_code = transform_code_object(code, transform)
#     751     break
#     752 except exc.RestartAnalysis as e:
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\bytecode_transformation.py:1361, in transform_code_object(code, transformations, safe)
#    1358 instructions = cleaned_instructions(code, safe)
#    1359 propagate_line_nums(instructions)
# -> 1361 transformations(instructions, code_options)
#    1362 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:231, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     229 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     230 try:
# --> 231     return fn(*args, **kwargs)
#     232 finally:
#     233     cleanup.close()
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py:662, in _compile.<locals>.transform(instructions, code_options)
#     660 try:
#     661     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 662         tracer.run()
#     663 except exc.UnspecializeRestartAnalysis:
#     664     speculation_log.clear()
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:2868, in InstructionTranslator.run(self)
#    2867 def run(self):
# -> 2868     super().run()
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:1052, in InstructionTranslatorBase.run(self)
#    1050 try:
#    1051     self.output.push_tx(self)
# -> 1052     while self.step():
#    1053         pass
#    1054 except TensorifyScalarRestartAnalysis:
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:962, in InstructionTranslatorBase.step(self)
#     959 self.update_block_stack(inst)
#     961 try:
# --> 962     self.dispatch_table[inst.opcode](self, inst)
#     963     return not self.output.should_exit
#     964 except TensorifyScalarRestartAnalysis:
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:2282, in InstructionTranslatorBase.BINARY_OP(self, inst)
#    2281 def BINARY_OP(self, inst):
# -> 2282     return _binary_op_lookup[inst.arg](self, inst)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:314, in stack_op.<locals>.impl(self, inst)
#     312 @functools.wraps(fn)
#     313 def impl(self: "InstructionTranslator", inst: Instruction):
# --> 314     self.push(fn_var.call_function(self, self.popn(nargs), {}))
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\builtin.py:1004, in BuiltinVariable.call_function(self, tx, args, kwargs)
#    1000 if not handler:
#    1001     self.call_function_handler_cache[key] = handler = self._make_handler(
#    1002         self.fn, [type(x) for x in args], bool(kwargs)
#    1003     )
# -> 1004 return handler(tx, args, kwargs)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\builtin.py:717, in BuiltinVariable._make_handler.<locals>.<lambda>(tx, args, kwargs)
#     714 handlers = []
#     716 if any(issubclass(t, LazyVariableTracker) for t in arg_types):
# --> 717     return lambda tx, args, kwargs: obj.call_function(
#     718         tx, [v.realize() for v in args], kwargs
#     719     )
#     721 if inspect.isclass(fn) and issubclass(fn, Exception):
#     723     def create_exception_class_object(
#     724         tx: "InstructionTranslator", args, kwargs
#     725     ):
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\builtin.py:1004, in BuiltinVariable.call_function(self, tx, args, kwargs)
#    1000 if not handler:
#    1001     self.call_function_handler_cache[key] = handler = self._make_handler(
#    1002         self.fn, [type(x) for x in args], bool(kwargs)
#    1003     )
# -> 1004 return handler(tx, args, kwargs)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\builtin.py:896, in BuiltinVariable._handle_insert_op_in_graph(self, tx, args, kwargs)
#     892         func = self.fn
#     894     fn_var = SourcelessBuilder.create(tx, func)
# --> 896     return dispatch_torch_function(tx, fn_var, args, kwargs)
#     898 fn = self.fn
#     899 try:
#     900     # Constant fold for constant tensor and python constants
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\torch_function.py:543, in dispatch_torch_function(tx, fn, args, kwargs)
#     540 types = TupleVariable([_get_subclass_type_var(tx, arg) for arg in overloaded_args])
#     542 if tx.symbolic_torch_function_state.in_torch_function_mode():
# --> 543     res = tx.symbolic_torch_function_state.call_torch_function_mode(
#     544         tx, fn, types, args, kwargs
#     545     )
#     546     if not (isinstance(res, ConstantVariable) and res.value is NotImplemented):
#     547         return res
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\torch_function.py:274, in SymbolicTorchFunctionState.call_torch_function_mode(self, tx, fn, types, args, kwargs)
#     272 def call_torch_function_mode(self, tx, fn, types, args, kwargs):
#     273     with self._pop_mode_for_inlining() as cur_mode:
# --> 274         return cur_mode.call_torch_function(tx, fn, types, args, kwargs)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\torch_function.py:392, in TorchFunctionModeVariable.call_torch_function(self, tx, fn, types, args, kwargs)
#     391 def call_torch_function(self, tx: "InstructionTranslator", fn, types, args, kwargs):
# --> 392     return call_torch_function(
#     393         tx,
#     394         self,
#     395         build_torch_function_fn(tx, self.value, self.source),
#     396         fn,
#     397         types,
#     398         args,
#     399         kwargs,
#     400     )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\torch_function.py:506, in call_torch_function(tx, torch_function_type, torch_function_var, fn, types, args, kwargs)
#     494 def call_torch_function(
#     495     tx, torch_function_type, torch_function_var, fn, types, args, kwargs
#     496 ):
#     497     # signature:
#     498     # def __torch_function__(cls, func, types, args=(), kwargs=None):
#     499     tf_args = (
#     500         torch_function_type,
#     501         fn,
#    (...)
#     504         VariableTracker.build(tx, kwargs),
#     505     )
# --> 506     return tx.inline_user_function_return(torch_function_var, tf_args, {})
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:903, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#     899 def inline_user_function_return(self, fn, args, kwargs):
#     900     """
#     901     A call to some user defined function by inlining it.
#     902     """
# --> 903     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:3072, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3069 @classmethod
#    3070 def inline_call(cls, parent, func, args, kwargs):
#    3071     with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 3072         return cls.inline_call_(parent, func, args, kwargs)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:3198, in InliningInstructionTranslator.inline_call_(parent, func, args, kwargs)
#    3196 try:
#    3197     with strict_ctx:
# -> 3198         tracer.run()
#    3199 except exc.ObservedException as e:
#    3200     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:1052, in InstructionTranslatorBase.run(self)
#    1050 try:
#    1051     self.output.push_tx(self)
# -> 1052     while self.step():
#    1053         pass
#    1054 except TensorifyScalarRestartAnalysis:
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:962, in InstructionTranslatorBase.step(self)
#     959 self.update_block_stack(inst)
#     961 try:
# --> 962     self.dispatch_table[inst.opcode](self, inst)
#     963     return not self.output.should_exit
#     964 except TensorifyScalarRestartAnalysis:
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:659, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     657     return handle_graph_break(self, inst, speculation.reason)
#     658 try:
# --> 659     return inner_fn(self, inst)
#     660 except Unsupported as excp:
#     661     if self.generic_context_manager_depth > 0:
#     662         # We don't support graph break under GenericContextWrappingVariable,
#     663         # If there is, we roll back to the checkpoint and fall back.
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:1736, in InstructionTranslatorBase.CALL_FUNCTION_EX(self, inst)
#    1734 # Map to a dictionary of str -> VariableTracker
#    1735 kwargsvars = kwargsvars.keys_as_python_constant()
# -> 1736 self.call_function(fn, argsvars.items, kwargsvars)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py:897, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     895 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     896     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 897 self.push(fn.call_function(self, args, kwargs))
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\torch.py:904, in TorchInGraphFunctionVariable.call_function(self, tx, args, kwargs)
#     896     return ConstantVariable.create(
#     897         self.as_python_constant()(
#     898             *[x.as_python_constant() for x in args],
#     899             **{k: v.as_python_constant() for k, v in kwargs.items()},
#     900         ),
#     901     )
#     903 if self.is_tensor_method():
# --> 904     return self.call_tensor_method(tx, args, kwargs)
#     906 special_handler = self._get_handlers().get(self.value)
#     907 if special_handler:
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\torch.py:1171, in TorchInGraphFunctionVariable.call_tensor_method(self, tx, args, kwargs)
#    1170 def call_tensor_method(self, tx, args, kwargs):
# -> 1171     return args[0].call_method(tx, self.get_function().__name__, args[1:], kwargs)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\tensor.py:1334, in NumpyNdarrayVariable.call_method(self, tx, name, args, kwargs)
#    1328     unimplemented(f"{name} is not modelled in torch._numpy")
#    1329 proxy = tx.output.create_proxy(
#    1330     "call_function",
#    1331     numpy_method_wrapper(name),
#    1332     *proxy_args_kwargs([self] + list(args), kwargs),
#    1333 )
# -> 1334 return NumpyNdarrayVariable.create(tx, proxy)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\tensor.py:1238, in NumpyNdarrayVariable.create(tx, proxy, **options)
#    1234 @staticmethod
#    1235 def create(tx: "InstructionTranslator", proxy, **options):
#    1236     from .builder import wrap_fx_proxy_cls
# -> 1238     return wrap_fx_proxy_cls(
#    1239         target_cls=NumpyNdarrayVariable,
#    1240         tx=tx,
#    1241         proxy=proxy,
#    1242         **options,
#    1243     )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\builder.py:2219, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2215 def wrap_fx_proxy_cls(
#    2216     target_cls, tx, proxy, example_value=None, subclass_type=None, **options
#    2217 ):
#    2218     if example_value is None:
# -> 2219         return _wrap_fx_proxy(
#    2220             target_cls, tx, proxy, example_value, subclass_type, **options
#    2221         )
#    2222     elif isinstance(example_value, torch.Tensor):
#    2223         return _wrap_fx_preexisting_tensor(
#    2224             target_cls, tx, proxy, example_value, subclass_type, **options
#    2225         )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\variables\builder.py:2315, in _wrap_fx_proxy(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2310 # See NOTE: [Deferring tensor pack/unpack hooks until runtime]
#    2311 with torch._dynamo.utils._disable_saved_tensors_hooks_during_tracing():
#    2312     # with preserve_rng_state():
#    2313     # only allow_non_graph_fake in this instance because we handle the non-fake
#    2314     # cases properly below.
# -> 2315     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    2317 return handle_traced_output(
#    2318     example_value, tx, proxy, options, subclass_type, target_cls
#    2319 )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\utils.py:2536, in get_fake_value(node, tx, allow_non_graph_fake)
#    2533     elif isinstance(cause, TypeError) and "argument" in str(cause):
#    2534         unimplemented(f"TypeError {node.target}: {cause}")
# -> 2536     raise TorchRuntimeError(str(e)).with_traceback(e.__traceback__) from None
#    2538 if not allow_non_graph_fake:
#    2539     _ = pytree.tree_map_only(
#    2540         torch.Tensor, functools.partial(ensure_graph_fake, tx=tx), ret_val
#    2541     )
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\utils.py:2471, in get_fake_value(node, tx, allow_non_graph_fake)
#    2469 try:
#    2470     with tx.fake_mode, enable_python_dispatcher():
# -> 2471         ret_val = wrap_fake_exception(
#    2472             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    2473         )
#    2474 except Unsupported:
#    2475     raise
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\utils.py:2017, in wrap_fake_exception(fn)
#    2015 def wrap_fake_exception(fn):
#    2016     try:
# -> 2017         return fn()
#    2018     except UnsupportedFakeTensorException as e:
#    2019         from .exc import unimplemented
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\utils.py:2472, in get_fake_value.<locals>.<lambda>()
#    2469 try:
#    2470     with tx.fake_mode, enable_python_dispatcher():
#    2471         ret_val = wrap_fake_exception(
# -> 2472             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    2473         )
#    2474 except Unsupported:
#    2475     raise
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\utils.py:2604, in run_node(tracer, node, args, kwargs, nnmodule)
#    2602         unimplemented(make_error_message(e), from_exc=e)
#    2603     except Exception as e:
# -> 2604         raise RuntimeError(make_error_message(e)).with_traceback(
#    2605             e.__traceback__
#    2606         ) from e
#    2608 raise AssertionError(op)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\utils.py:2586, in run_node(tracer, node, args, kwargs, nnmodule)
#    2584 try:
#    2585     if op == "call_function":
# -> 2586         return node.target(*args, **kwargs)
#    2587     elif op == "call_method":
#    2588         return getattr(args[0], node.target)(*args[1:], **kwargs)
#
# File c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\utils.py:2929, in numpy_method_wrapper.__call__(self, *args, **kwargs)
#    2927 if isinstance(obj, torch.Tensor):
#    2928     obj = tnp.ndarray(obj)
# -> 2929 method_callable = getattr(obj, self.method)
#    2930 out = method_callable(*args[1:], **kwargs)
#    2931 return numpy_to_tensor(out)
#
# TorchRuntimeError: Failed running call_function <Wrapped method <original add>>(*(FakeTensor(..., device='cuda:0', size=(1,), dtype=torch.int32), FakeTensor(..., device='cuda:0', size=(1,), dtype=torch.int32)), **{}):
# 'ndarray' object has no attribute 'add'
#
# from user code:
#    File "C:\Users\Vady\AppData\Local\Temp\ipykernel_25080\3522929497.py", line 6, in f
#     return a + b
#   File "c:\Users\Vady\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_device.py", line 104, in __torch_function__
#     return func(*args, **kwargs)
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
#
#
# You can suppress this exception and fall back to eager by setting:
#     import torch._dynamo
#     torch._dynamo.config.suppress_errors = True
